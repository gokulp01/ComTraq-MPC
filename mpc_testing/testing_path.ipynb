# %%
import numpy as np
import matplotlib.pyplot as plt

optimal_path = np.load('first_optimal_path.npy')
plt.plot(optimal_path[:,0], optimal_path[:,1], 'r-')
plt.show()

# %%
len(optimal_path)
# Out:
# 89
